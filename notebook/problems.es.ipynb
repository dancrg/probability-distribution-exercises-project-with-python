# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %% [markdown]
# DISTRIBUCION NORMAL:

# %%
# TODO

from scipy.stats import norm

def dnorm(X, miu, desv):                           # Calcula el valor de densidad (punto en la curva correspondiente al valor x)
    result = norm.pdf(x=X, loc=miu, scale=desv)
    return result

def pnorm(X, miu, desv):                           # Calcula el acumulado de la funcion normal
    result = norm.cdf(x=X, loc=miu, scale=desv)
    return result

def qnorm(Q, miu, desv):                           # Calcula la función cuantil a partir de la distribución normal
    result = norm.ppf(q=Q, loc=miu, scale=desv)
    return result

def rnorm(miu, desv, tamano):                     # Genera variables aleatorias a partir de la distribución normal
   result = norm.rvs(loc=miu, scale=desv, size=tamano)
   return result

# %%
X = 100
miu = 100
desv = 4
Q = 0.5
tamano = 20

import numpy as np
np.random.seed(42)

print(f"Density of NORMAL distribution for value X:                    (PDF)    {dnorm(X, miu, desv)}\n")

print(f"Probability that a NORMAL will take a value less than X:       (CDF)    {pnorm(X, miu, desv)}\n")

print(f"Which value of a NORMAL has a cumulative probability of Q?     (PPF)    {qnorm(Q, miu, desv)}\n")

print(f"Generate some random values from a NORMAL distribution:        (RVS)    {rnorm(miu, desv, tamano)}\n")
# Out:
# Density of NORMAL distribution for value X:                    (PDF)    0.09973557010035818
#
# Probability that a NORMAL will take a value less than X:       (CDF)    0.5
#
# Which value of a NORMAL has a cumulative probability of Q?     (PPF)    100.0
#
# Generate some random values from a NORMAL distribution:        (RVS)    [101.98685661  99.4469428  102.59075415 106.09211943  99.0633865
#   99.06345217 106.31685126 103.06973892  98.12210246 102.17024017
#   98.14632923  98.13708099 100.96784909  92.34687902  93.10032867
#   97.75084988  95.94867552 101.25698933  96.3679037   94.35078519]

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(42)

miu = 100
desv = 4
tamano = 50

data = rnorm(miu, desv, tamano)               # CREO LOS VALORES ALEATORIOS
data_ppf = np.linspace(0,1,tamano)            # CREO LOS PERCENTILES

print(f'DATOS: {data}\n')
print(f'PERCENTILES: {data_ppf}\n')

pdf = dnorm(data, miu, desv)
cdf = pnorm(data, miu, desv)                  
ppf = qnorm(data_ppf, miu, desv)

fig, axis = plt.subplots(3, 1, figsize = (4, 8))

axis[0].stem(data, pdf, "r-")                       # GRAFICO DE DENSIDAD           x VS f(x)
axis[0].set_title("Densidad")
axis[0].set_xlabel("x")
axis[0].set_ylabel("f(x)")

axis[1].stem(data, cdf, "b-")                       # GRAFICO DE PROB ACUMULADA     x VS p
axis[1].set_title("Probabilidad Acumulada")
axis[1].set_xlabel("x")
axis[1].set_ylabel("Prob Acumulada")

axis[2].stem(data_ppf, ppf, "g-")                   # GRAFICO DE VALORES X          percentiles VS x
axis[2].set_title("Percentiles vs X")
axis[2].set_xlabel("Percentil")
axis[2].set_ylabel("x")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# DATOS: [101.98685661  99.4469428  102.59075415 106.09211943  99.0633865
#   99.06345217 106.31685126 103.06973892  98.12210246 102.17024017
#   98.14632923  98.13708099 100.96784909  92.34687902  93.10032867
#   97.75084988  95.94867552 101.25698933  96.3679037   94.35078519
#  105.86259508  99.0968948  100.27011282  94.30100726  97.8224691
#  100.44369036  95.39602569 101.50279207  97.59744524  98.833225
#   97.59317355 107.40911274  99.9460111   95.76915628 103.29017965
#   95.1166254  100.83545438  92.1613195   94.6872558  100.78744494
#  102.95386632 100.68547312  99.53740687  98.79558522  94.08591204
#   97.12062317  98.15744492 104.2284889  101.37447316  92.94783938]
#
# PERCENTILES: [0.         0.02040816 0.04081633 0.06122449 0.08163265 0.10204082
#  0.12244898 0.14285714 0.16326531 0.18367347 0.20408163 0.2244898
#  0.24489796 0.26530612 0.28571429 0.30612245 0.32653061 0.34693878
#  0.36734694 0.3877551  0.40816327 0.42857143 0.44897959 0.46938776
# ...

# %% [markdown]
# DISTRIBUCION UNIFORME (CONTINUA)

# %%
from scipy.stats import uniform

def duniforme(X,a,b):                                      # Calculo de la densidad (PDF)
  densidad = uniform.pdf(x=X, loc=a, scale=b-a)
  return densidad

def puniforme(X,a,b):                                      # Calculo de probabilidad (CDF)
  probabilidad = uniform.cdf(x=X, loc=a, scale=b-a)       
  return probabilidad

def xuniforme(Q,a,b):                                      # Calculo de X dado el percentil (PPF)
  equis = uniform.ppf(q=Q, loc=a, scale=b-a)
  return equis

def runiforme(a,b,tamano):                                 # Creacion de valores aleatorios (RVS)
  datos = uniform.rvs(loc=a, scale=b-a, size=tamano)
  return datos

# %%
X = 60
a = 0
b = 100
Q = 0.90
tamano = 15 

import numpy as np
np.random.seed(42)

print(f"Density of UNIFORM distribution for value X:                    (PDF)    {duniforme(X, a, b)}\n")

print(f"Probability that a UNIFORM will take a value less than X:       (CDF)    {puniforme(X, a, b)}\n")

print(f"Which value of a UNIFORM has a cumulative probability of Q?     (PPF)    {xuniforme(Q, a, b)}\n")

print(f"Generate some random values from a UNIFORM distribution:        (RVS)    {runiforme(a, b, tamano)}\n")
# Out:
# Density of UNIFORM distribution for value X:                    (PDF)    0.01
#
# Probability that a UNIFORM will take a value less than X:       (CDF)    0.6
#
# Which value of a UNIFORM has a cumulative probability of Q?     (PPF)    90.0
#
# Generate some random values from a UNIFORM distribution:        (RVS)    [37.45401188 95.07143064 73.19939418 59.86584842 15.60186404 15.59945203
#   5.80836122 86.61761458 60.11150117 70.80725778  2.05844943 96.99098522
#  83.24426408 21.23391107 18.18249672]

# %%
import matplotlib.pyplot as plt
### import numpy as np

### np.random.seed(42)

a = 100
b = 200
tamano = 21

### data = uniform.rvs(a, b, tamano)              # CREO LOS VALORES ALEATORIOS (Puede no incluir a. No incluye b)
data = np.linspace(a, b, tamano)                
data_ppf = np.linspace(0, 1, tamano)          # CREO LOS PERCENTILES

print(f'DATOS: {data}\n')
print(f'PERCENTILES: {data_ppf}\n')

pdf = duniforme(data, a, b)                   
cdf = puniforme(data, a, b)                   
ppf = xuniforme(data_ppf, a, b)               

fig, axis = plt.subplots(3, 1, figsize = (4, 8))

axis[0].stem(data, pdf, "r-")                         # GRAFICO DE DENSIDAD           x VS f(x)
axis[0].set_title("Densidad")
axis[0].set_xlabel("x")
axis[0].set_ylabel("f(x)")

axis[1].stem(data, cdf, "b-")                         # GRAFICO DE PROB ACUMULADA     x VS p
axis[1].set_title("Probabilidad Acumulada")
axis[1].set_xlabel("x")
axis[1].set_ylabel("Prob Acumulada")

axis[2].stem(data_ppf, ppf, "g-")                     # GRAFICO DE VALORES X          percentiles VS x
axis[2].set_title("Percentiles vs X")
axis[2].set_xlabel("Percentil")
axis[2].set_ylabel("x")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# DATOS: [100. 105. 110. 115. 120. 125. 130. 135. 140. 145. 150. 155. 160. 165.
#  170. 175. 180. 185. 190. 195. 200.]
#
# PERCENTILES: [0.   0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65
#  0.7  0.75 0.8  0.85 0.9  0.95 1.  ]
